# %%
import pandas as pd

# %%
pd.read_csv(r'2021FuelConsumptionRatings.csv')
# Out:
#      MODELYEAR   MAKE              MODEL   VEHICLECLASS  ENGINESIZE  \
# 0         2021  Acura                ILX        Compact         2.4
# 1         2021  Acura                NSX     Two-seater         3.5
# 2         2021  Acura         RDX SH-AWD     SUV: Small         2.0
# 3         2021  Acura  RDX SH-AWD A-SPEC     SUV: Small         2.0
# 4         2021  Acura         TLX SH-AWD        Compact         2.0
# ..         ...    ...                ...            ...         ...
# 930       2021  Volvo        XC40 T5 AWD     SUV: Small         2.0
# 931       2021  Volvo        XC60 T5 AWD     SUV: Small         2.0
# 932       2021  Volvo        XC60 T6 AWD     SUV: Small         2.0
# 933       2021  Volvo        XC90 T5 AWD  SUV: Standard         2.0
# 934       2021  Volvo        XC90 T6 AWD  SUV: Standard         2.0
#
#      CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# 0            4          AM8        Z                   9.9
# ...

# %%
ls
# Out:
# 2021FuelConsumptionRatings.csv
# EXAM_01.ipynb
# Exam 2.ipynb
# LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# LUSID Excel - Manage Orders.xlsx
# Untitled Folder/
# assessment.ipynb
# breast cancer.ipynb
# pandas and numpy Day01_Practice.ipynb
# pandas_Day01.ipynb
# pandas_Day02.ipynb
# pandas_Day03.ipynb
# pandas_Day04 03 HW.ipynb
# pandas_Day04.ipynb
# pandas_Day05.ipynb

# %%
pwd
# Out:
# '/Users/anilreddykunta/Desktop/Anil/PYTHON/Pandas_ipynb'

# %%
# pd.read_csv('2021FuelConsumptionRatings.csv') # should be in same directory

# %%
# DataFrame

df = pd.read_csv(r'2021FuelConsumptionRatings.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('2021FuelConsumptionRatings.csv')
# Out:
#      MODELYEAR   MAKE              MODEL   VEHICLECLASS  ENGINESIZE  \
# 0         2021  Acura                ILX        Compact         2.4
# 1         2021  Acura                NSX     Two-seater         3.5
# 2         2021  Acura         RDX SH-AWD     SUV: Small         2.0
# 3         2021  Acura  RDX SH-AWD A-SPEC     SUV: Small         2.0
# 4         2021  Acura         TLX SH-AWD        Compact         2.0
# ..         ...    ...                ...            ...         ...
# 930       2021  Volvo        XC40 T5 AWD     SUV: Small         2.0
# 931       2021  Volvo        XC60 T5 AWD     SUV: Small         2.0
# 932       2021  Volvo        XC60 T6 AWD     SUV: Small         2.0
# 933       2021  Volvo        XC90 T5 AWD  SUV: Standard         2.0
# 934       2021  Volvo        XC90 T6 AWD  SUV: Standard         2.0
#
#      CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# 0            4          AM8        Z                   9.9
# ...

# %%
# not considering the column names
pd.read_csv('2021FuelConsumptionRatings.csv', header=None)
# Out:
#             0      1                  2              3           4   \
# 0    MODELYEAR   MAKE              MODEL   VEHICLECLASS  ENGINESIZE
# 1         2021  Acura                ILX        Compact         2.4
# 2         2021  Acura                NSX     Two-seater         3.5
# 3         2021  Acura         RDX SH-AWD     SUV: Small           2
# 4         2021  Acura  RDX SH-AWD A-SPEC     SUV: Small           2
# ..         ...    ...                ...            ...         ...
# 931       2021  Volvo        XC40 T5 AWD     SUV: Small           2
# 932       2021  Volvo        XC60 T5 AWD     SUV: Small           2
# 933       2021  Volvo        XC60 T6 AWD     SUV: Small           2
# 934       2021  Volvo        XC90 T5 AWD  SUV: Standard           2
# 935       2021  Volvo        XC90 T6 AWD  SUV: Standard           2
#
#             5             6         7                     8   \
# 0    CYLINDERS  TRANSMISSION  FUELTYPE  FUELCONSUMPTION_CITY
# ...

# %%
# make model columns are considered as index
pd.read_csv('2021FuelConsumptionRatings.csv', names=['a','b','c'])
# Out:
#                                                                                                                                                         a  \
# MODELYEAR MAKE  MODEL             VEHICLECLASS  ENGINESIZE CYLINDERS TRANSMISSION FUELTYPE FUELCONSUMPTION_CITY FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB
# 2021      Acura ILX               Compact       2.4        4         AM8          Z        9.9                  7                                     8.6
#                 NSX               Two-seater    3.5        6         AM9          Z        11.1                 10.8                                   11
#                 RDX SH-AWD        SUV: Small    2          4         AS10         Z        11                   8.6                                   9.9
#                 RDX SH-AWD A-SPEC SUV: Small    2          4         AS10         Z        11.3                 9.1                                  10.3
# ...

# %%
pd.read_csv('2021FuelConsumptionRatings.csv', names=['a','b','c','d','e','f','g','h','i','j','k','l','m','n'])
# Out:
#              a      b                  c              d           e  \
# 0    MODELYEAR   MAKE              MODEL   VEHICLECLASS  ENGINESIZE
# 1         2021  Acura                ILX        Compact         2.4
# 2         2021  Acura                NSX     Two-seater         3.5
# 3         2021  Acura         RDX SH-AWD     SUV: Small           2
# 4         2021  Acura  RDX SH-AWD A-SPEC     SUV: Small           2
# ..         ...    ...                ...            ...         ...
# 931       2021  Volvo        XC40 T5 AWD     SUV: Small           2
# 932       2021  Volvo        XC60 T5 AWD     SUV: Small           2
# 933       2021  Volvo        XC60 T6 AWD     SUV: Small           2
# 934       2021  Volvo        XC90 T5 AWD  SUV: Standard           2
# 935       2021  Volvo        XC90 T6 AWD  SUV: Standard           2
#
#              f             g         h                     i  \
# 0    CYLINDERS  TRANSMISSION  FUELTYPE  FUELCONSUMPTION_CITY
# ...

# %%
pd.read_csv('2021FuelConsumptionRatings.csv',sep=',')
# Out:
#      MODELYEAR   MAKE              MODEL   VEHICLECLASS  ENGINESIZE  \
# 0         2021  Acura                ILX        Compact         2.4
# 1         2021  Acura                NSX     Two-seater         3.5
# 2         2021  Acura         RDX SH-AWD     SUV: Small         2.0
# 3         2021  Acura  RDX SH-AWD A-SPEC     SUV: Small         2.0
# 4         2021  Acura         TLX SH-AWD        Compact         2.0
# ..         ...    ...                ...            ...         ...
# 930       2021  Volvo        XC40 T5 AWD     SUV: Small         2.0
# 931       2021  Volvo        XC60 T5 AWD     SUV: Small         2.0
# 932       2021  Volvo        XC60 T6 AWD     SUV: Small         2.0
# 933       2021  Volvo        XC90 T5 AWD  SUV: Standard         2.0
# 934       2021  Volvo        XC90 T6 AWD  SUV: Standard         2.0
#
#      CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# 0            4          AM8        Z                   9.9
# ...

# %%
df
# Out:
#      MODELYEAR   MAKE              MODEL   VEHICLECLASS  ENGINESIZE  \
# 0         2021  Acura                ILX        Compact         2.4
# 1         2021  Acura                NSX     Two-seater         3.5
# 2         2021  Acura         RDX SH-AWD     SUV: Small         2.0
# 3         2021  Acura  RDX SH-AWD A-SPEC     SUV: Small         2.0
# 4         2021  Acura         TLX SH-AWD        Compact         2.0
# ..         ...    ...                ...            ...         ...
# 930       2021  Volvo        XC40 T5 AWD     SUV: Small         2.0
# 931       2021  Volvo        XC60 T5 AWD     SUV: Small         2.0
# 932       2021  Volvo        XC60 T6 AWD     SUV: Small         2.0
# 933       2021  Volvo        XC90 T5 AWD  SUV: Standard         2.0
# 934       2021  Volvo        XC90 T6 AWD  SUV: Standard         2.0
#
#      CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# 0            4          AM8        Z                   9.9
# ...

# %%
df = pd.read_csv(r'2021FuelConsumptionRatings.csv')

# %%
df =pd.read_csv('2021FuelConsumptionRatings.csv',skip_blank_lines= True)

# %%
df
# Out:
#      MODELYEAR   MAKE              MODEL   VEHICLECLASS  ENGINESIZE  \
# 0         2021  Acura                ILX        Compact         2.4
# 1         2021  Acura                NSX     Two-seater         3.5
# 2         2021  Acura         RDX SH-AWD     SUV: Small         2.0
# 3         2021  Acura  RDX SH-AWD A-SPEC     SUV: Small         2.0
# 4         2021  Acura         TLX SH-AWD        Compact         2.0
# ..         ...    ...                ...            ...         ...
# 930       2021  Volvo        XC40 T5 AWD     SUV: Small         2.0
# 931       2021  Volvo        XC60 T5 AWD     SUV: Small         2.0
# 932       2021  Volvo        XC60 T6 AWD     SUV: Small         2.0
# 933       2021  Volvo        XC90 T5 AWD  SUV: Standard         2.0
# 934       2021  Volvo        XC90 T6 AWD  SUV: Standard         2.0
#
#      CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# 0            4          AM8        Z                   9.9
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# MODELYEAR                     int64
# MAKE                         object
# MODEL                        object
# VEHICLECLASS                 object
# ENGINESIZE                  float64
# CYLINDERS                     int64
# TRANSMISSION                 object
# FUELTYPE                     object
# FUELCONSUMPTION_CITY        float64
# FUELCONSUMPTION_HWY         float64
# FUELCONSUMPTION_COMB        float64
# FUELCONSUMPTION_COMB_MPG      int64
# CO2EMISSIONS                  int64
# dtype: object

# %%
df.head(2)
# Out:
#    MODELYEAR   MAKE MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 0       2021  Acura   ILX      Compact         2.4          4          AM8
# 1       2021  Acura   NSX   Two-seater         3.5          6          AM9
#
#   FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0        Z                   9.9                  7.0                   8.6
# 1        Z                  11.1                 10.8                  11.0
#
#    FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                        33           199
# 1                        26           256

# %%
df.tail(3)
# Out:
#      MODELYEAR   MAKE        MODEL   VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 932       2021  Volvo  XC60 T6 AWD     SUV: Small         2.0          4
# 933       2021  Volvo  XC90 T5 AWD  SUV: Standard         2.0          4
# 934       2021  Volvo  XC90 T6 AWD  SUV: Standard         2.0          4
#
#     TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 932          AS8        Z                  11.7                  8.6
# 933          AS8        Z                  11.5                  8.4
# 934          AS8        Z                  12.1                  8.5
#
#      FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 932                  10.3                        27           240
# 933                  10.1                        28           236
# 934                  10.5                        27           245

# %%
df.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
# df['ENGINESIZE','CYLINDERS','CO2EMISSIONS']
a = df['ENGINESIZE']

# %%
a
# Out:
# 0      2.4
# 1      3.5
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 930    2.0
# 931    2.0
# 932    2.0
# 933    2.0
# 934    2.0
# Name: ENGINESIZE, Length: 935, dtype: float64

# %%
df['ENGINESIZE','CYLINDERS','CO2EMISSIONS']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('ENGINESIZE', 'CYLINDERS', 'CO2EMISSIONS')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[['ENGINESIZE','CYLINDERS','CO2EMISSIONS']]
# Out:
#      ENGINESIZE  CYLINDERS  CO2EMISSIONS
# 0           2.4          4           199
# 1           3.5          6           256
# 2           2.0          4           232
# 3           2.0          4           242
# 4           2.0          4           230
# ..          ...        ...           ...
# 930         2.0          4           219
# 931         2.0          4           230
# 932         2.0          4           240
# 933         2.0          4           236
# 934         2.0          4           245
#
# [935 rows x 3 columns]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a
# Out:
# 0      2.4
# 1      3.5
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 930    2.0
# 931    2.0
# 932    2.0
# 933    2.0
# 934    2.0
# Name: ENGINESIZE, Length: 935, dtype: float64

# %%
a1=df[['ENGINESIZE','CYLINDERS','CO2EMISSIONS']]

# %%
type(a1)
# Out:
# pandas.core.frame.DataFrame

# %%
a1
# Out:
#      ENGINESIZE  CYLINDERS  CO2EMISSIONS
# 0           2.4          4           199
# 1           3.5          6           256
# 2           2.0          4           232
# 3           2.0          4           242
# 4           2.0          4           230
# ..          ...        ...           ...
# 930         2.0          4           219
# 931         2.0          4           230
# 932         2.0          4           240
# 933         2.0          4           236
# 934         2.0          4           245
#
# [935 rows x 3 columns]

# %%
df[['ENGINESIZE']]
# Out:
#      ENGINESIZE
# 0           2.4
# 1           3.5
# 2           2.0
# 3           2.0
# 4           2.0
# ..          ...
# 930         2.0
# 931         2.0
# 932         2.0
# 933         2.0
# 934         2.0
#
# [935 rows x 1 columns]

# %%
c = df['ENGINESIZE']

# %%
type(c)
# Out:
# pandas.core.series.Series

# %%
c
# Out:
# 0      2.4
# 1      3.5
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 930    2.0
# 931    2.0
# 932    2.0
# 933    2.0
# 934    2.0
# Name: ENGINESIZE, Length: 935, dtype: float64

# %%
b = df[['ENGINESIZE']]

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
b
# Out:
#      ENGINESIZE
# 0           2.4
# 1           3.5
# 2           2.0
# 3           2.0
# 4           2.0
# ..          ...
# 930         2.0
# 931         2.0
# 932         2.0
# 933         2.0
# 934         2.0
#
# [935 rows x 1 columns]

# %%
c
# Out:
# 0      2.4
# 1      3.5
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 930    2.0
# 931    2.0
# 932    2.0
# 933    2.0
# 934    2.0
# Name: ENGINESIZE, Length: 935, dtype: float64

# %%
pd.read_excel('LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx')
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# ...

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx')
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
d = pd.read_excel('LUSID Excel - Manage Orders.xlsx')

# %%
d.shape
# Out:
# (70, 19)

# %%
d.head()
# Out:
#    Unnamed: 0                                   Unnamed: 1 Unnamed: 2  \
# 0         NaN  This sheet allows you to manage executions:        NaN
# 1         NaN                           1. List executions        NaN
# 2         NaN                             2. Get execution        NaN
# 3         NaN                         3. Upsert executions        NaN
# 4         NaN                                          NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# ...

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx', sheet_name='Allocations')
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df = pd.read_excel('LUSID Excel - Manage Orders.xlsx')

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18'],
#       dtype='object')

# %%
df = pd.ExcelFile('LUSID Excel - Manage Orders.xlsx')

# %%
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx', sheet_name='Blocks')
# Out:
#     Unnamed: 0                               Unnamed: 1  \
# 0          NaN  This sheet allows you to manage Blocks:
# 1          NaN                            1. ListBlocks
# 2          NaN                              2. GetBlock
# 3          NaN                          3. UpsertBlocks
# 4          NaN                                      NaN
# 5          NaN                                      NaN
# 6          NaN                                      NaN
# 7          NaN                                      NaN
# 8          NaN                  1. Get a list of blocks
# 9          NaN                                      NaN
# 10         NaN                                    asAt:
# 11         NaN                                      NaN
# 12         NaN                                  filter:
# 13         NaN                                      NaN
# 14         NaN                            propertyKeys:
# 15         NaN                                      NaN
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
