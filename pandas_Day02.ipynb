# %%
import pandas as pd

# %%
pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')
# Out:
# [                Player       Span  Mat Inns  NO  Runs   HS    Ave   BF  \
#  0           AB Agarkar  2006-2007    4    2   0    15   14   7.50   11
#  1             KK Ahmed  2018-2019   14    1   1     1   1*      -    1
#  2            S Aravind  2015-2015    1    -   -     -    -      -    -
#  3       Arshdeep Singh  2022-2023   26    5   5     6   2*      -   10
#  4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  160
#  ..                 ...        ...  ...  ...  ..   ...  ...    ...  ...
#  97       R Vinay Kumar  2010-2013    9    1   1     2   2*      -    4
#  98   Washington Sundar  2017-2023   35   14   4   107   50  10.70   70
#  99            SA Yadav  2021-2023   48   46  10  1675  117  46.52  953
#  100           UT Yadav  2012-2022    9    2   1    22  20*  22.00   21
#  101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  863
#
#           SR 100  50  0   4s  6s
#  0    136.36   0   0  0    2   0
#  1    100.00   0   0  0    0   0
# ...

# %%
df = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 3

# %%
df[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
df[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v New Zealand at Ahmedabad, 3rd T20I, Fe...
# 2  India v New Zealand at Lucknow, 2nd T20I, Jan ...
# 3  India v New Zealand at Ranchi, 1st T20I, Jan 2...

# %%
df[0]
# Out:
#                 Player       Span  Mat Inns  NO  Runs   HS    Ave   BF  \
# 0           AB Agarkar  2006-2007    4    2   0    15   14   7.50   11
# 1             KK Ahmed  2018-2019   14    1   1     1   1*      -    1
# 2            S Aravind  2015-2015    1    -   -     -    -      -    -
# 3       Arshdeep Singh  2022-2023   26    5   5     6   2*      -   10
# 4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  160
# ..                 ...        ...  ...  ...  ..   ...  ...    ...  ...
# 97       R Vinay Kumar  2010-2013    9    1   1     2   2*      -    4
# 98   Washington Sundar  2017-2023   35   14   4   107   50  10.70   70
# 99            SA Yadav  2021-2023   48   46  10  1675  117  46.52  953
# 100           UT Yadav  2012-2022    9    2   1    22  20*  22.00   21
# 101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  863
#
#          SR 100  50  0   4s  6s
# 0    136.36   0   0  0    2   0
# 1    100.00   0   0  0    0   0
# ...

# %%
df[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
df[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v New Zealand at Ahmedabad, 3rd T20I, Fe...
# 2  India v New Zealand at Lucknow, 2nd T20I, Jan ...
# 3  India v New Zealand at Ranchi, 1st T20I, Jan 2...

# %%
df[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df[4]
#
# IndexError: list index out of range

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
df1.head()
# Out:
#            Player       Span  Mat Inns  NO Runs   HS    Ave   BF      SR 100  \
# 0      AB Agarkar  2006-2007    4    2   0   15   14   7.50   11  136.36   0
# 1        KK Ahmed  2018-2019   14    1   1    1   1*      -    1  100.00   0
# 2       S Aravind  2015-2015    1    -   -    -    -      -    -       -   -
# 3  Arshdeep Singh  2022-2023   26    5   5    6   2*      -   10   60.00   0
# 4        R Ashwin  2010-2022   65   19  12  184  31*  26.28  160  115.00   0
#
#   50  0  4s 6s
# 0  0  0   2  0
# 1  0  0   0  0
# 2  -  -   -  -
# 3  0  0   0  0
# 4  0  0  17  4

# %%
df1.tail()
# Out:
#                 Player       Span  Mat Inns  NO  Runs   HS    Ave   BF  \
# 97       R Vinay Kumar  2010-2013    9    1   1     2   2*      -    4
# 98   Washington Sundar  2017-2023   35   14   4   107   50  10.70   70
# 99            SA Yadav  2021-2023   48   46  10  1675  117  46.52  953
# 100           UT Yadav  2012-2022    9    2   1    22  20*  22.00   21
# 101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  863
#
#          SR 100  50  0   4s  6s
# 97    50.00   0   0  0    0   0
# 98   152.85   0   1  4   10   6
# 99   175.76   3  13  3  150  96
# 100  104.76   0   0  0    2   0
# 101  136.38   0   8  1   77  74

# %%
df1.dtypes
# Out:
# Player    object
# Span      object
# Mat        int64
# Inns      object
# NO        object
# Runs      object
# HS        object
# Ave       object
# BF        object
# SR        object
# 100       object
# 50        object
# 0         object
# 4s        object
# 6s        object
# dtype: object

# %%
df1[['Player','Span']]
# Out:
#                 Player       Span
# 0           AB Agarkar  2006-2007
# 1             KK Ahmed  2018-2019
# 2            S Aravind  2015-2015
# 3       Arshdeep Singh  2022-2023
# 4             R Ashwin  2010-2022
# ..                 ...        ...
# 97       R Vinay Kumar  2010-2013
# 98   Washington Sundar  2017-2023
# 99            SA Yadav  2021-2023
# 100           UT Yadav  2012-2022
# 101       Yuvraj Singh  2007-2017
#
# [102 rows x 2 columns]

# %%
df1[['Player','Span']]
# Out:
#                 Player       Span
# 0           AB Agarkar  2006-2007
# 1             KK Ahmed  2018-2019
# 2            S Aravind  2015-2015
# 3       Arshdeep Singh  2022-2023
# 4             R Ashwin  2010-2022
# ..                 ...        ...
# 97       R Vinay Kumar  2010-2013
# 98   Washington Sundar  2017-2023
# 99            SA Yadav  2021-2023
# 100           UT Yadav  2012-2022
# 101       Yuvraj Singh  2007-2017
#
# [102 rows x 2 columns]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
 #df1.to_csv('batting_India.csv')

# %%
open batting_India.csv
# Out:
#   Input In [21]
#     open batting_India.csv
#          ^
# SyntaxError: invalid syntax

# %%
df1.to_csv('Batting_India.csv')

# %%
open Batting_India.csv
# Out:
#   Input In [23]
#     open Batting_India.csv
#          ^
# SyntaxError: invalid syntax

# %%
df1.to_csv('Batting_India1.csv',index=False)

# %%
df1.to_csv('Batting_India2.csv',index=True)

# %%
df = pd.read_csv('Batting_India.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          Player       Span  Mat Inns  NO Runs   HS    Ave   BF  \
# 0           0      AB Agarkar  2006-2007    4    2   0   15   14   7.50   11
# 1           1        KK Ahmed  2018-2019   14    1   1    1   1*      -    1
# 2           2       S Aravind  2015-2015    1    -   -    -    -      -    -
# 3           3  Arshdeep Singh  2022-2023   26    5   5    6   2*      -   10
# 4           4        R Ashwin  2010-2022   65   19  12  184  31*  26.28  160
#
#        SR 100 50  0  4s 6s
# 0  136.36   0  0  0   2  0
# 1  100.00   0  0  0   0  0
# 2       -   -  -  -   -  -
# 3   60.00   0  0  0   0  0
# 4  115.00   0  0  0  17  4

# %%
pd.read_csv('Batting_India.csv')
# Out:
#      Unnamed: 0             Player       Span  Mat Inns  NO  Runs   HS    Ave  \
# 0             0         AB Agarkar  2006-2007    4    2   0    15   14   7.50
# 1             1           KK Ahmed  2018-2019   14    1   1     1   1*      -
# 2             2          S Aravind  2015-2015    1    -   -     -    -      -
# 3             3     Arshdeep Singh  2022-2023   26    5   5     6   2*      -
# 4             4           R Ashwin  2010-2022   65   19  12   184  31*  26.28
# ..          ...                ...        ...  ...  ...  ..   ...  ...    ...
# 97           97      R Vinay Kumar  2010-2013    9    1   1     2   2*      -
# 98           98  Washington Sundar  2017-2023   35   14   4   107   50  10.70
# 99           99           SA Yadav  2021-2023   48   46  10  1675  117  46.52
# 100         100           UT Yadav  2012-2022    9    2   1    22  20*  22.00
# 101         101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02
#
# ...

# %%
pd.read_csv('Batting_India1.csv')
# Out:
#                 Player       Span  Mat Inns  NO  Runs   HS    Ave   BF  \
# 0           AB Agarkar  2006-2007    4    2   0    15   14   7.50   11
# 1             KK Ahmed  2018-2019   14    1   1     1   1*      -    1
# 2            S Aravind  2015-2015    1    -   -     -    -      -    -
# 3       Arshdeep Singh  2022-2023   26    5   5     6   2*      -   10
# 4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  160
# ..                 ...        ...  ...  ...  ..   ...  ...    ...  ...
# 97       R Vinay Kumar  2010-2013    9    1   1     2   2*      -    4
# 98   Washington Sundar  2017-2023   35   14   4   107   50  10.70   70
# 99            SA Yadav  2021-2023   48   46  10  1675  117  46.52  953
# 100           UT Yadav  2012-2022    9    2   1    22  20*  22.00   21
# 101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  863
#
#          SR 100  50  0   4s  6s
# 0    136.36   0   0  0    2   0
# 1    100.00   0   0  0    0   0
# ...

# %%
df3= pd.read_csv('Batting_India1.csv')

# %%
df3.head()
# Out:
#            Player       Span  Mat Inns  NO Runs   HS    Ave   BF      SR 100  \
# 0      AB Agarkar  2006-2007    4    2   0   15   14   7.50   11  136.36   0
# 1        KK Ahmed  2018-2019   14    1   1    1   1*      -    1  100.00   0
# 2       S Aravind  2015-2015    1    -   -    -    -      -    -       -   -
# 3  Arshdeep Singh  2022-2023   26    5   5    6   2*      -   10   60.00   0
# 4        R Ashwin  2010-2022   65   19  12  184  31*  26.28  160  115.00   0
#
#   50  0  4s 6s
# 0  0  0   2  0
# 1  0  0   0  0
# 2  -  -   -  -
# 3  0  0   0  0
# 4  0  0  17  4

# %%
pd.read_csv('Batting_India1.csv')
# Out:
#                 Player       Span  Mat Inns  NO  Runs   HS    Ave   BF  \
# 0           AB Agarkar  2006-2007    4    2   0    15   14   7.50   11
# 1             KK Ahmed  2018-2019   14    1   1     1   1*      -    1
# 2            S Aravind  2015-2015    1    -   -     -    -      -    -
# 3       Arshdeep Singh  2022-2023   26    5   5     6   2*      -   10
# 4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  160
# ..                 ...        ...  ...  ...  ..   ...  ...    ...  ...
# 97       R Vinay Kumar  2010-2013    9    1   1     2   2*      -    4
# 98   Washington Sundar  2017-2023   35   14   4   107   50  10.70   70
# 99            SA Yadav  2021-2023   48   46  10  1675  117  46.52  953
# 100           UT Yadav  2012-2022    9    2   1    22  20*  22.00   21
# 101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  863
#
#          SR 100  50  0   4s  6s
# 0    136.36   0   0  0    2   0
# 1    100.00   0   0  0    0   0
# ...

# %% [markdown]
# #dictionaries
# d = """
# {"name": "Anil",
# "email": "anil@123",
# "tech": ["ineu",'ml','dl'],
# "platform": ['tech ','kids', 'ine']
# }
# """

# %%
d = """
{"name": "Anil",
"email": "anil@123",
"tech": ["ineu","ml","dl"],
"platform": ["tech","kids", "ine"]
}
"""

# %%
type(d)
# Out:
# str

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 pd.DataFrame(d)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:756, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     753 # For data is scalar
#     754 else:
#     755     if index is None or columns is None:
# --> 756         raise ValueError("DataFrame constructor not properly called!")
#     758     # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     759     # expected "Union[Union[Union[ExtensionArray, ndarray],
#     760     # Index, Series], Sequence[Any]]"
#     761     index = ensure_index(index)  # type: ignore[arg-type]
#
# ValueError: DataFrame constructor not properly called!

# %%
import json # java script

# %%
json.load(d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 json.load(d)
#
# File ~/opt/anaconda3/lib/python3.9/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# ...

# %%
json.loads(d)
# Out:
# {'name': 'Anil',
#  'email': 'anil@123',
#  'tech': ['ineu', 'ml', 'dl'],
#  'platform': ['tech', 'kids', 'ine']}

# %%
result = json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
result
# Out:
# {'name': 'Anil',
#  'email': 'anil@123',
#  'tech': ['ineu', 'ml', 'dl'],
#  'platform': ['tech', 'kids', 'ine']}

# %%
pd.DataFrame(result)
# Out:
#    name     email  tech platform
# 0  Anil  anil@123  ineu     tech
# 1  Anil  anil@123    ml     kids
# 2  Anil  anil@123    dl      ine

# %%
pd.read_json(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 pd.read_json(result)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
f = """
{"name": "Anil",
"email": "anil@123",
"tech": ["ineu","ml","dl"],
"platform": ["tech","kids", "ine","sdd"]
}
"""

# %% [markdown]
# json.load(d)
# result = json.loads(d)
# result
# pd.DataFrame(result)

# %%
json.loads(f)
answer = json.loads(f)

answer
# Out:
# {'name': 'Anil',
#  'email': 'anil@123',
#  'tech': ['ineu', 'ml', 'dl'],
#  'platform': ['tech', 'kids', 'ine', 'sdd']}

# %%
# All arrays must be of the same lengt
pd.DataFrame(answer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 pd.DataFrame(answer)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
# ...

# %%
result
# Out:
# {'name': 'Anil',
#  'email': 'anil@123',
#  'tech': ['ineu', 'ml', 'dl'],
#  'platform': ['tech', 'kids', 'ine']}

# %%
result['name']
# Out:
# 'Anil'

# %%
result['tech']
# Out:
# ['ineu', 'ml', 'dl']

# %%
pd.DataFrame(result['name'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 pd.DataFrame(result['name'])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:756, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     753 # For data is scalar
#     754 else:
#     755     if index is None or columns is None:
# --> 756         raise ValueError("DataFrame constructor not properly called!")
#     758     # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     759     # expected "Union[Union[Union[ExtensionArray, ndarray],
#     760     # Index, Series], Sequence[Any]]"
#     761     index = ensure_index(index)  # type: ignore[arg-type]
#
# ValueError: DataFrame constructor not properly called!

# %%
pd.DataFrame(result['tech'])
# Out:
#       0
# 0  ineu
# 1    ml
# 2    dl
